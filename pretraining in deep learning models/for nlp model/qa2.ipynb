# %%
from transformer import pipeline, AutoModelForSequenceClassification, AutoTokenizor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformer import pipeline, AutoModelForSequenceClassification, AutoTokenizor
#
# ModuleNotFoundError: No module named 'transformer'
