# %%
from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizor
#
# ImportError: cannot import name 'pipeline' from 'transformers' (c:\Users\QHS 006\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\__init__.py)

# %%
model_name="textattack/bert-base-uncased-SST"
