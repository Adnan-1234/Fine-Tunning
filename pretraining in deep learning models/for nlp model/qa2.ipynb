# %%
from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizer
# Out:
# W0523 00:38:34.149000 8420 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizor
#
# ImportError: cannot import name 'AutoTokenizor' from 'transformers' (c:\Users\QHS 006\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\__init__.py)

# %%
model_name="textattack/bert-base-uncased-SST-2"

# %%
tokenizer=AutoTokenizer.from_pretrained(model_name)
model=AutoModelForSequenceClassification(model_name)
